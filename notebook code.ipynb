# %%
import pandas as pd

wine2 = pd.read_csv('wine_clean.csv')

wine_winery = wine2[['province', 'points', 'price', 'variety']]
winex4 = pd.get_dummies(wine_winery, drop_first=True)

y4 = winex4['points'].values
X4 = winex4.drop('points', axis=1).values

# %%
from pycaret.regression import *

exp_reg = setup(wine_winery, target = 'points')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_dc22d768_a858_11ea_97f7_dad04770afe5row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_dc22d768_a858_11ea_97f7_dad04770afe5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row0_col1" class="data row0 col1" >6437</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row3_col1" class="data row3 col1" >(120959, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row4_col1" class="data row4 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row5_col1" class="data row5 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row10_col1" class="data row10 col1" >(96767, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row11_col1" class="data row11 col1" >(67736, 1119)</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row12_col1" class="data row12 col1" >(29031, 1119)</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dc22d768_a858_11ea_97f7_dad04770afe5level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_dc22d768_a858_11ea_97f7_dad04770afe5row18_col0" class="data row18 col0" >Transformation Method </td>

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=245)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               20:53:47
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Model
# ETC        . . . . . . . . . . . . . . . . . .  0.0 Seconds Remaining
#                           Model           MAE           MSE          RMSE  \
# 0              Ridge Regression  2.001400e+00  6.339100e+00  2.517500e+00
# 1                Bayesian Ridge  2.002400e+00  6.340100e+00  2.517700e+00
# 2        Least Angle Regression  2.006200e+00  6.361000e+00  2.521800e+00
# 3   Orthogonal Matching Pursuit  2.017000e+00  6.425400e+00  2.534600e+00
# 4                   Elastic Net  2.130500e+00  7.154100e+00  2.674400e+00
# 5              Lasso Regression  2.131900e+00  7.154700e+00  2.674500e+00
# 6  Lasso Least Angle Regression  2.478000e+00  9.210500e+00  3.034700e+00
# 7  Passive Aggressive Regressor  2.797800e+00  1.912700e+01  4.265300e+00
# 8       Random Sample Consensus  3.197362e+06  3.270571e+16  1.325290e+08
# 9             Linear Regression  2.933957e+06  5.080542e+16  1.224214e+08
#
#              R2   RMSLE        MAPE
# 0  3.118000e-01  0.0281      0.0227
# 1  3.117000e-01  0.0281      0.0227
# 2  3.094000e-01  0.0281      0.0227
# 3  3.024000e-01  0.0283      0.0229
# 4  2.233000e-01  0.0298      0.0241
# 5  2.232000e-01  0.0298      0.0242
# 6 -1.000000e-04  0.0340      0.0281
# 7 -1.086700e+00  0.0434      0.0313
# 8 -3.595474e+15  0.6335  36659.0528
# 9 -5.569901e+15  0.3904  33615.3896
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9ff5ccfe3077> in <module>
# ----> 1 compare_models()
#
# ~\Anaconda3\lib\site-packages\pycaret\regression.py in compare_models(blacklist, fold, round, sort, turbo)
#    2918             Xtrain,Xtest = data_X.iloc[train_i], data_X.iloc[test_i]
#    2919             ytrain,ytest = data_y.iloc[train_i], data_y.iloc[test_i]
# -> 2920             model.fit(Xtrain,ytrain)
#    2921             pred_ = model.predict(Xtest)
#    2922
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_theil_sen.py in fit(self, X, y)
#     386                            verbose=self.verbose)(
#     387             delayed(_lstsq)(X, y, index_list[job], self.fit_intercept)
# --> 388             for job in range(n_jobs))
#     389         weights = np.vstack(weights)
#     390         self.n_iter_, coefs = _spatial_median(weights,
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_theil_sen.py in _lstsq(X, y, indices, fit_intercept)
#     189         y_subpopulation[:n_subsamples] = y[subset]
#     190         weights[index] = lstsq(X_subpopulation,
# --> 191                                y_subpopulation)[1][:n_features]
#     192
#     193     return weights
#
# KeyboardInterrupt:

# %%
ridge = create_model('ridge')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0